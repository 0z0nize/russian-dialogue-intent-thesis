# %% [markdown]
# # Создание структуры папок на Google Drive
#
# Этот ноутбук создаёт необходимую структуру папок проекта на Google Drive.
#
# Запустите все ячейки по порядку в Google Colab.

# %% [markdown]
# ## 1. Подключение Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Создание папок

# %%
import os

BASE_DIR = "/content/drive/MyDrive/russian-dialogue-intent-thesis"

FOLDERS = [
    "data/raw",
    "data/interim",
    "data/processed",
    "data/annotation",
    "models",
    "results/tables",
    "results/figures",
    "results/logs",
    "results/predictions",
    "exports",
]

for folder in FOLDERS:
    path = os.path.join(BASE_DIR, folder)
    os.makedirs(path, exist_ok=True)
    print(f"Создана папка: {path}")
# Out:
# Создана папка: /content/drive/MyDrive/russian-dialogue-intent-thesis/data/raw
# Создана папка: /content/drive/MyDrive/russian-dialogue-intent-thesis/data/interim
# Создана папка: /content/drive/MyDrive/russian-dialogue-intent-thesis/data/processed
# Создана папка: /content/drive/MyDrive/russian-dialogue-intent-thesis/data/annotation
# Создана папка: /content/drive/MyDrive/russian-dialogue-intent-thesis/models
# Создана папка: /content/drive/MyDrive/russian-dialogue-intent-thesis/results/tables
# Создана папка: /content/drive/MyDrive/russian-dialogue-intent-thesis/results/figures
# Создана папка: /content/drive/MyDrive/russian-dialogue-intent-thesis/results/logs
# Создана папка: /content/drive/MyDrive/russian-dialogue-intent-thesis/results/predictions
# Создана папка: /content/drive/MyDrive/russian-dialogue-intent-thesis/exports

# %% [markdown]
# ## 3. Проверка структуры

# %%
for folder in FOLDERS:
    path = os.path.join(BASE_DIR, folder)
    exists = os.path.isdir(path)
    print(f"{'OK' if exists else 'НЕТ'}: {path}")
# Out:
# OK: /content/drive/MyDrive/russian-dialogue-intent-thesis/data/raw
# OK: /content/drive/MyDrive/russian-dialogue-intent-thesis/data/interim
# OK: /content/drive/MyDrive/russian-dialogue-intent-thesis/data/processed
# OK: /content/drive/MyDrive/russian-dialogue-intent-thesis/data/annotation
# OK: /content/drive/MyDrive/russian-dialogue-intent-thesis/models
# OK: /content/drive/MyDrive/russian-dialogue-intent-thesis/results/tables
# OK: /content/drive/MyDrive/russian-dialogue-intent-thesis/results/figures
# OK: /content/drive/MyDrive/russian-dialogue-intent-thesis/results/logs
# OK: /content/drive/MyDrive/russian-dialogue-intent-thesis/results/predictions
# OK: /content/drive/MyDrive/russian-dialogue-intent-thesis/exports
